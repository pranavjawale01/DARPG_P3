# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import os
# import speech_recognition as sr
# from pydub import AudioSegment

# # Function to convert audio file to WAV format
# def convert_to_wav(audio_file):
#     sound = AudioSegment.from_file(audio_file)
#     audio_file_wav = audio_file.replace(".mp3", ".wav")  # Convert to WAV format
#     sound.export(audio_file_wav, format="wav")
#     return audio_file_wav

# # Function to transcribe audio file to text
# def transcribe_audio(audio_file):
#     recognizer = sr.Recognizer()
#     with sr.AudioFile(audio_file) as source:
#         audio_data = recognizer.record(source)  # Read the entire audio file
#         text = recognizer.recognize_google(audio_data, language="hi-IN")  # Recognize speech using Google Speech Recognition API
#     return text

# # Directory containing audio files
# audio_folder = "path/to/audio/folder"

# # Loop through audio files in the folder
# for file in os.listdir(audio_folder):
#     if file.endswith(".mp3"):
#         audio_file_path = os.path.join(audio_folder, file)

#         # Convert audio file to WAV format
#         audio_file_wav = convert_to_wav(audio_file_path)

#         # Transcribe audio to text
#         text = transcribe_audio(audio_file_wav)

#         # Save transcribed text to a text file
#         text_file_path = audio_file_path.replace(".mp3", ".txt")
#         with open(text_file_path, "w", encoding="utf-8") as text_file:
#             text_file.write(text)

#         print(f"Transcription saved to: {text_file_path}")

# %%
pip install SpeechRecognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 40.9 MB/s eta 0:00:00
# ...

# %%
pip install pydub

# %%
import os
import speech_recognition as sr
from pydub import AudioSegment

# Function to convert audio file to WAV format
def convert_to_wav(audio_file):
    sound = AudioSegment.from_file(audio_file)
    audio_file_wav = audio_file.replace(".mp3", ".wav")  # Convert to WAV format
    sound.export(audio_file_wav, format="wav")
    return audio_file_wav

# Function to transcribe audio file to text
def transcribe_audio(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)  # Read the entire audio file
        text = recognizer.recognize_google(audio_data, language="hi-IN")  # Recognize speech using Google Speech Recognition API
    return text

# Directory containing audio files
audio_folder = "/content/drive/MyDrive/DARPG/DARPG_3/problem_statement_3"

# Directory to save text files
output_folder = "/content/drive/MyDrive/DARPG/DARPG_3/Output_v2"

# Loop through audio files in the folder
for file in os.listdir(audio_folder):
    if file.endswith(".mp3"):
        audio_file_path = os.path.join(audio_folder, file)

        # Convert audio file to WAV format
        audio_file_wav = convert_to_wav(audio_file_path)

        # Transcribe audio to text
        text = transcribe_audio(audio_file_wav)

        # Create output directory if it doesn't exist
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        # Save transcribed text to a text file in the output directory
        output_file_path = os.path.join(output_folder, file.replace(".mp3", ".txt"))
        with open(output_file_path, "w", encoding="utf-8") as text_file:
            text_file.write(text)

        print(f"Transcription saved to: {output_file_path}")
# Out:
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/_6307107294.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6001323013.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6003716436.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6200541923.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6005960443.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6005094236.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6200617875.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6268558344.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6299363500.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6204030424.txt
# Transcription saved to: /content/drive/MyDrive/DARPG/DARPG_3/Output_v2/6204634893.txt
# ...
